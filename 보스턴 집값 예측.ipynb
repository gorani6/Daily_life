# %%
import pandas as pd
import tensorflow as tf

# %%
보스턴 = pd.read_csv('/content/drive/MyDrive/csv/boston-housing.csv')
print(보스턴.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
  
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
x = tf.keras.layers.Input(shape=[13])
y = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.4257
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.2229
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.6173
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.8563
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.1227
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.2411
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7005
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.4669
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.4093
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.8733

# %%
model.predict(독립[0:5])
# Out:
# array([[30.244455],
#        [24.971474],
#        [31.560417],
#        [30.324059],
#        [29.950289]], dtype=float32)

# %%
종속[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
#모델의 수식 확인
model.get_weights()
# Out:
# [array([[-0.08884446],
#         [ 0.0536028 ],
#         [-0.04191826],
#         [ 2.9060516 ],
#         [ 1.3324846 ],
#         [ 5.1342793 ],
#         [-0.00833633],
#         [-0.99157   ],
#         [ 0.1743212 ],
#         [-0.01098851],
#         [-0.33756196],
#         [ 0.01306279],
#         [-0.48184222]], dtype=float32), array([3.568036], dtype=float32)]

# %%
import pandas as pd
import tensorflow as tf

# %%
data1 = pd.read_csv('/content/drive/MyDrive/csv/lemonade.csv')
data1.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
독립 = data1[['온도']]
종속 = data1[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
#모델 만들기

x = tf.keras.layers.Input(shape=[1])
y = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
#모델 학습

model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4228e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4220e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4214e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4194e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4175e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4160e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4151e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4143e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4137e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4130e-04

# %%
# 모델 이용

model.predict(독립)
# Out:
# array([[40.026012],
#        [42.0206  ],
#        [44.01519 ],
#        [46.009777],
#        [48.004364],
#        [49.998955]], dtype=float32)

# %%
model.predict([[15]])
# Out:
# array([[30.05307]], dtype=float32)
